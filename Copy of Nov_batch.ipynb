# %% [markdown]
# Class 1

# %%
# Creating a variable
# int
_num1_=100
num1=100
Num1=100
Num_1=100
# 1num=100
# @num1=100
# -num1-=100

# %%
name="Tom"
print(name)
print(type(name))
num=1000
print(num)
print(type(num))
num2=187.987
print(num2)
print(type(num2))
num3=True
print(num3)
print(type(num3))
# Out:
# Tom
# <class 'str'>
# 1000
# <class 'int'>
# 187.987
# <class 'float'>
# True
# <class 'bool'>

# %%
_name_="Jerry"
# concatenation
print("my favorite cartoon name is "+_name_)

no1=1999
no2=283
sum=no1+no2
print("The addition of two values",sum)
print(type(sum))
no3=False
# Out:
# my favorite cartoon name is Jerry
# The addition of two values 2282
# <class 'int'>

# %%
# Boolean
print(10>9)
# Out:
# True

# %%
a=10
b="10"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-4cb3ee92adbf> in <module>
#       1 a=10
#       2 b="10"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
c=int(input("Enter the value :"))
d=int(input("Enter the value :"))
print("The addition of two values are:",(c+d))
# Out:
# Enter the value :10
# Enter the value :10
# The addition of two values are: 20

# %% [markdown]
# **Class 2**

# %%
'''Collection datatypes in python
List
Tuple
Dictionary
Set'''
# Out:
# 'Collection datatypes in python\nList\nTuple\nDictionary\nSet'

# %%
# List -> ordered collection of datatypes ,[],mutable
mylist=["task","Sequence","public","details",63464,True,37.47]
print(len(mylist))
print(type(mylist))
print(mylist)
# mylist.reverse()
# print(mylist)

# Update
mylist[5]=False
print(mylist)
# Append
mylist.append("data")
print(mylist)
# insert
mylist.insert(2,"Data")
print(mylist)
# remove
mylist.remove("data")
print(mylist)
# delete
del mylist[3]
print(mylist)
# Out:
# 7
# <class 'list'>
# ['task', 'Sequence', 'public', 'details', 63464, True, 37.47]
# ['task', 'Sequence', 'public', 'details', 63464, False, 37.47]
# ['task', 'Sequence', 'public', 'details', 63464, False, 37.47, 'data']
# ['task', 'Sequence', 'Data', 'public', 'details', 63464, False, 37.47, 'data']
# ['task', 'Sequence', 'Data', 'public', 'details', 63464, False, 37.47]
# ['task', 'Sequence', 'Data', 'details', 63464, False, 37.47]

# %%
# import re
# b="Hello all"
# a=re.search("all",b)
# print(b[6:9])
# Out:
# all

# %%
# Indexing
print(mylist[-1])
# Out:
# 37.47

# %%
# Slicing-> is used to obtain a sequence of elements
print(mylist[0:3])
# Out:
# ['task', 'Sequence', 'public']

# %%
print(mylist[2:])
# Out:
# ['public', 'details', 63464, True, 37.47]

# %%
print(mylist[:3])
# Out:
# ['task', 'Sequence', 'public']

# %%
print(mylist[4:6])
# Out:
# [63464, True]

# %%
print(mylist[-3:-1])
# Out:
# [63464, True]

# %%
print(mylist[-1:-3])
# Out:
# []

# %%
print(mylist[:-1])
# Out:
# [37.47, True, 63464, 'details', 'public', 'Sequence']

# %%
# Start , stop, step index
mylist=["task","Sequence","public","details",63464,True,37.47]
print(mylist[0:6:4])
# Out:
# ['task', 63464]

# %%
a=[1,2,3,45,56]
b=[43,34,7,8]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 45, 56, 43, 34, 7, 8]

# %% [markdown]
# **Class 3**

# %%
#Tuple -> ordered collection of datatype, (),immutable
mytuple=("Data","Access","Denied",65,36.47,True)
print(mytuple)
print(mytuple[5])
print(mytuple[2:5])
# Out:
# ('Data', 'Access', 'Denied', 65, 36.47, True)
# True
# ('Denied', 65, 36.47)

# %%
# update 
mytuple[0]="Value"
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-abaf20f573e7> in <module>
#       1 # update
# ----> 2 mytuple[0]="Value"
#       3 print(mytuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#append
mytuple.append("Data")
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8accf7e86bb7> in <module>
#       1 #append
# ----> 2 mytuple.append("Data")
#       3 print(mytuple)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#insert
mytuple.insert(4,10)
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-14e3b62dbf2b> in <module>
#       1 #insert
# ----> 2 mytuple.insert(4,10)
#       3 print(mytuple)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
mytuple.pop[1]
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d819377b3450> in <module>
# ----> 1 mytuple.pop[1]
#       2 print(mytuple)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
mytuple.remove(True)
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-680c968f4898> in <module>
# ----> 1 mytuple.remove(True)
#       2 print(mytuple)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
del mytuple
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-130a3e49f4ff> in <module>
# ----> 1 del mytuple
#       2 print(mytuple)
#
# NameError: name 'mytuple' is not defined

# %%
#Dictionary :- data can be stored in terms of keys and values,{}
mydic={"a":5,
       "Brand":"Dell",
       "Yearofmaking":2022,
       "Color":"Black"

}
print(mydic)
# Out:
# {'a': 5, 'Brand': 'Dell', 'Yearofmaking': 2022, 'Color': 'Black'}

# %%
mydic[3]="Task"
print(mydic)
# Out:
# {'a': 5, 'Brand': 'Dell', 'Yearofmaking': 2022, 'Color': 'Black', 3: 'Task'}

# %%
mydic["a"]=50
print(mydic)
# Out:
# {'a': 50, 'Brand': 'Dell', 'Yearofmaking': 2022, 'Color': 'Black', 3: 'Task'}

# %%
mydic["b"]=mydic.pop("a")
print(mydic)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-b44450dc8679> in <module>
# ----> 1 mydic["b"]=mydic.pop("a")
#       2 print(mydic)
#
# KeyError: 'a'

# %%
dic={1:2,2:3,5:4,6:5}

dic[6]=dic[7]=9
print(dic)
# Out:
# {1: 2, 2: 3, 5: 4, 6: 9, 7: 9}

# %%
a={"b":5,"x":6}
print(a)
a["c"]=a.pop("x")
print(a)
# Out:
# {'b': 5, 'x': 6}
# {'b': 5, 'c': 6}

# %%
# Set -> Unordered collection of datatypes,{},doesn't support duplicate values
myset={"data","data1",2,2}
print(myset)
# Out:
# {'data', 2, 'data1'}

# %%
print(myset[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7d1724384d42> in <module>
# ----> 1 print(myset[0])
#
# TypeError: 'set' object is not subscriptable

# %%
myset.add(3)
print(myset)
# Out:
# {3, 'data', 2, 'data1'}

# %%
set1={1,2,3,34}
set2={1,4,67,9,0}
set4={"a","a","df",236}
set3=set1.union(set2)
print(set3)
set5=set1|set2|set4
print(set5)
# Out:
# {0, 1, 2, 3, 34, 67, 4, 9}
# {0, 1, 2, 3, 34, 67, 4, 9, 'a', 236, 'df'}

# %%
set1={1,2,3,34}
set2={1,4,67,9,0}
set4={1,23,567,0}
set3=set1.intersection(set2)
print(set3)
set5=set1&set2&set4
print(set5)
set1.remove(1)
print(set1)
# Out:
# {1}
# {1}
# {2, 3, 34}

# %%
set1.clear()
print(set1)
# Out:
# set()

# %%
del set1
print(set1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-f4494dd05139> in <module>
# ----> 1 del set1
#       2 print(set1)
#
# NameError: name 'set1' is not defined

# %%
# Function-> a set of instruction will be executed whenever you call or invoke it.

def func():
  print('Hello All')
func()
# Out:
# Hello All

# %%
def add(num1,num2):
  print("The addition of two values are :",(num1+num2))
add(45,55)
# Out:
# The addition of two values are : 100

# %% [markdown]
# **Class 4**

# %%
def add(n1,n2):
 print("The addition is :",(n1+n2))
add(12,12)
# Out:
# The addition is : 24

# %%
def add1():
  x=input("Enter the name:")
  print("My favourite cartoon name is",x)
add1()
# Out:
# Enter the name:x
# My favourite cartoon name is x

# %%
def sub():
  x=int(input("Enter the first value:"))
  y=int(input("Enter the second value:"))
  print("The addition of two values are ",(x+y))
sub()
# Out:
# Enter the first value:1
# Enter the second value:1
# The addition of two values are  2

# %%
def sum():
  x= input("Enter the first number:")
  y = input("Enter the second number:")
  sum = int(x) + int(y)
  print("the sum is", sum)
sum()
# Out:
# Enter the first number:e
# Enter the second number:2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-67c8950f825d> in <module>
#       4   sum = int(x) + int(y)
#       5   print("the sum is", sum)
# ----> 6 sum()
#
# <ipython-input-14-67c8950f825d> in sum()
#       2   x= input("Enter the first number:")
#       3   y = input("Enter the second number:")
# ----> 4   sum = int(x) + int(y)
#       5   print("the sum is", sum)
#       6 sum()
#
# ValueError: invalid literal for int() with base 10: 'e'

# %%
# Iterator
# Iter and next

list=["Task","value","Assigned","Schedule"]
print(list)
# Out:
# ['Task', 'value', 'Assigned', 'Schedule']

# %%
myiterator=iter(list)
print(next(myiterator))
# Out:
# Task

# %%
print(next(myiterator))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-23-3337a1468eac> in <module>
# ----> 1 print(next(myiterator))
#
# StopIteration:

# %%
list=["Task","value","Assigned","Schedule"]
for value in list:
  print(value)
# Out:
# Task
# value
# Assigned
# Schedule

# %%
list1=[1,2,34,56,0,78]
sum=0
mul=1
for x in list1:
  sum=sum+x
  mul=mul*x

  print("The value is sum is",sum)  
  print("The value of multiplication is",mul)
# Out:
# The value is sum is 1
# The value of multiplication is 1
# The value is sum is 3
# The value of multiplication is 2
# The value is sum is 37
# The value of multiplication is 68
# The value is sum is 93
# The value of multiplication is 3808
# The value is sum is 93
# The value of multiplication is 0
# The value is sum is 171
# The value of multiplication is 0

# %%
for a in range(10):
  print("The values are ",a)
# Out:
# The values are  0
# The values are  1
# The values are  2
# The values are  3
# The values are  4
# The values are  5
# The values are  6
# The values are  7
# The values are  8
# The values are  9

# %%
def play(a,b):
    print(a+b)
play(10,20)
# Out:
# 30

# %%
lisy=[1,2,3,4,6,8,9,5]
sub=10
for i in lisy:
    sub=sub-i;
mul=1 
for j in lisy:
    mul=mul*j
print(sub)
print(mul)
# Out:
# -28
# 51840

# %%
# Sequence
list1=[1,2,4,56]
print(1 in list1)
print(list*2)
print(len(list1))
print("The minimum value of list1 is ",min(list1))
print("The maximum value of list is",max(list1))
# Out:
# True
# ['Task', 'value', 'Assigned', 'Schedule', 'Task', 'value', 'Assigned', 'Schedule']
# 4
# The minimum value of list1 is  1
# The maximum value of list is 56

# %%
print(56 not in list1)
# Out:
# False

# %%
seq="Helohbhvgl"
print(seq.index("l",3))
# Out:
# 9

# %%
seq1=[1,2,3,4,5,6,7,5,41,12]
print(seq1.index(5,6,41))
# Out:
# 7

# %%
# String formatting
# Operator,Format,fstring,string template class
print("Good %s student " %("evening"))
# Out:
# Good evening student

# %%
print("Task %s today %s " %("completed","Thank you"))
# Out:
# Task completed today Thank you

# %%
Successfully(s,l)
Partition(i)
Evening mansion(i)

# %% [markdown]
# **Class 5**

# %%
# Files
# They are three differnt
# Read mode(r)(r+)
# Write mode(w)(w+)
# Append mode(a)(a+)

# %%
myfile=open("Python.txt","r")
print(myfile.read())
# Out:
# # Read mode(r)(r+)
# # Write mode(w)(w+)
# # Append mode(a)(a+)

# %%
myfile.close()

# %%
myfile=open("Python.txt","w")
myfile.write("This is written by the user")
# Out:
# 27

# %%
myfile=open("Python.txt","r")
print(myfile.read())
# Out:
# This is written by the user

# %%
myfile=open("Python.txt","a")
myfile.write("\n This is written by the programmer")
# Out:
# 35

# %%
myfile=open("Python.txt","r")
print(myfile.read())
# Out:
# This is written by the user
#  This is written by the programmer
#  This is written by the programmer

# %%
data=int(input("Enter the odd or even numbers:"))
if (data %2==0):
  print("It is an even number")
else:
  print("It is an odd number")
# Out:
# Enter the odd or even numbers:784537589
# It is an odd number

# %%
marks=int(input("Enter the marks:"))
if marks >35:
  print("You are pass")
elif marks >= 34:
  print("You are Fail")
else:
  print("Invalid number")
# Out:
# Enter the marks:10
# Invalid number

# %%
a=10
b=20
if a>b:
  print("A is greater than B")
elif a<b:
  print("B is greater than A")  
else:
  print("A is equal to B")
# Out:
# B is greater than A

# %%
'''ASSIGNMENT ONE
Examples on r+,w+,a+
Create a simple calculator using python
two inputs and operators should be selected by the user'''

# %% [markdown]
# **Class 6**

# %%
def name(a):
  print("Hello",a)
name("Tom")
# Out:
# Hello Tom

# %%
def func():
  print("Hello all")
func()
# Out:
# Hello all

# %%
# Advance argument passing

# positional arguments
def details(name,batch,year):
  print("Hi my name",name ,"from batch",batch,"in the year",year)
details("Nov",2022,"Tom")
# Out:
# Hi my name Nov from batch 2022 in the year Tom

# %%
def data(a,b,c,d):
  print(a,b,c,d)
data(4,3,5,1)
# Out:
# 4 3 5 1

# %%
# Keyword arguments
def details(name,batch,year):
  print("Hi my name",name ,"from batch",batch,"in the year",year)
details(batch="Nov",year=2022,name="Tom")
# Out:
# Hi my name Tom from batch Nov in the year 2022

# %%
def details(name,batch,year):
  print("Hi my name",name ,"from batch",batch,"in the year",year)
details("Tom",year=2022,batch="Nov")
# Out:
# Hi my name Tom from batch Nov in the year 2022

# %%
# default arguments
def details(name="Jerry",batch="Nov",year=2022):
  print("Hi my name",name ,"from batch",batch,"in the year",year)
details("tom","oct",2021)
# Out:
# Hi my name tom from batch oct in the year 2021

# %%
def data(name="charan",brand="Iphone",date=15):
  print("my name is ",name,"I purchased a",brand,"mobile on",date)
data("sai","samsung",16)
# Out:
# my name is  sai I purchased a samsung mobile on 16

# %%
def details(name="Jerry",batch="Oct",year=2022):
    print("Hi, my name is",name,"from", batch, "batch","in the year",year)
    
details("Tom",year=2021,batch="Oct")
# Out:
# Hi, my name is Tom from Oct batch in the year 2021

# %%
# *args
def college(Teacher,*args):
  print("The teacher name is",Teacher)
  
  for roll_no in args:
    print("The student rollno are",roll_no)
college("Tom",24,45,471,37,475,3,24,12,)
# Out:
# The teacher name is Tom
# The student rollno are 24
# The student rollno are 45
# The student rollno are 471
# The student rollno are 37
# The student rollno are 475
# The student rollno are 3
# The student rollno are 24
# The student rollno are 12

# %%
def college(Teacher,*args,**kwargs):
  print("The teacher name is",Teacher)
  
  for roll_no in args:
    print("The student rollno are",roll_no)
  for subject in kwargs:
    print(subject,kwargs[subject])   

college("Tom",1,2,3,4,6,7,8,8,9,math=30,english=10)
# Out:
# The teacher name is Tom
# The student rollno are 1
# The student rollno are 2
# The student rollno are 3
# The student rollno are 4
# The student rollno are 6
# The student rollno are 7
# The student rollno are 8
# The student rollno are 8
# The student rollno are 9
# math 30
# english 10

# %%
def college ( teacher ,*args,**kwargs):
  print("the teacher name is" Teacher)
  For roll_no in args:
  print ("the application no are" ,application no )
for subject in **kwargs :
print (subject,kwargs[subject])
college("sanjay",1432,1516,1718,1918,1000)
1918,1000)
# Out:
#   File "<ipython-input-32-9e3de04fdb71>", line 2
#     print("the teacher name is" Teacher)
#                                       ^
# SyntaxError: invalid syntax

# %%
list=[2,456,78,12,3,5,5,6,0]

for i in list:
  if i %2==0:
    print(i,'is an even number')
  else:
    print(i,'is an odd number')
# Out:
#   File "<ipython-input-33-4f911bfd0c02>", line 3
#     for i in list:
#                 ^
# SyntaxError: invalid character in identifier

# %%
list2 =[1,13,12,14,15,23]
for values in list2:
  if(values % 2 == 0):
    print(values,"is even")
  else:
    print(values,"is odd")
# Out:
# 1 is odd
# 13 is odd
# 12 is even
# 14 is even
# 15 is odd
# 23 is odd

# %% [markdown]
# Class7

# %%
# Comprehension
# List
list1=[1,2,34,5,6,78,789]
print(type(list1))
# Out:
# <class 'list'>

# %%
even_list=[]
for value in list1:
  if value %2==0:
    even_list.append(value)
print(even_list)
# Out:
# [2, 34, 6, 78]

# %%
odd_list=[]
for value in list1:
  if value %2!=0:
    odd_list.append(value)
print(odd_list)
# Out:
# [1, 5, 789]

# %%
# List comprehension
evenlist=[x for x in list1 if x %2==0]
print(evenlist)
# Out:
# [2, 34, 6, 78]

# %%
list1.sort()
asclist=[i for i in list1]
print(asclist)
# Out:
# [1, 2, 5, 6, 34, 78, 789]

# %%
evenlist.sort()
print(evenlist)
# Out:
# [2, 6, 34, 78]

# %%
myList = [21, 10, 18, 9];
myList.sort(reverse=True);
print(myList);
# Out:
# [21, 18, 10, 9]

# %%
# Dictionary
mydic={}
list1=[1,2,34,5,6,78,789,1,2]
for value in list1:
  mydic[value]=value**2
print(type(mydic))
# Out:
# <class 'dict'>

# %%
# Dictionary comprehension

mydict = {x: x**2 for x in list1}
print(mydict)
# Out:
# {1: 1, 2: 4, 34: 1156, 5: 25, 6: 36, 78: 6084, 789: 622521}

# %%
mydic={value: value**2 for value in list1 }
print(mydic)
# Out:
# {1: 1, 2: 4, 34: 1156, 5: 25, 6: 36, 78: 6084, 789: 622521}

# %%
even_set=set()
for y in list1:
  if y %3==0:
    even_set.add(y)
print(even_set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-0ffbe4f53f88> in <module>
#       2 for y in list1:
#       3   if y %3==0:
# ----> 4     even_set.add(y)
#       5 print(even_set)
#       6
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
# Set comprehension
list1=[1,2,3,4,5,8]

notdivisibleby3_set={y for y in list1 if y%3!=0}
print(notdivisibleby3_set)
print(type(notdivisibleby3_set))
# Out:
# {1, 2, 4, 5, 8}
# <class 'set'>

# %%
'''Write a program code to take a list of numbers and find whether the numbers in the given list 
is divisible by 7 or not'''
# Out:
# 'Write a program code to take a list of numbers and find whether the numbers in the given list \nis divisible by 7 or not'

# %%
data_list=[1,25,23,456,54,6,984,6,456,8912,8512,631,9,4196,196,1,6]
data={numbers for numbers in data_list if numbers%7==0 }
print(data)
# Out:
# {8512, 196}

# %%
list1=[21,14,7]

if value %7 ==0:
  print("the values are divisible by 7")
elif value %7!=0:
  print("the values are not divisible by 7")
# Out:
# the values are not divisible by 7

# %%
list2 = [700,245,234,10,7,123]
for x in list2:
  if x%7 == 0:
    print(x)
  else: 
    print("Value is not divisible")
# Out:
# 700
# 245
# Value is not divisible
# Value is not divisible
# 7
# Value is not divisible

# %%
lst = []
n = int(input("Enter number of elements : "))
for i in range(0, 5):
    ele = int(input())
    lst.append(ele)
seven_set=[y if y%7==0 else "not divisible" for y in lst]
print(seven_set)
# Out:
# Enter number of elements : 545
# 4
# 4
# 121
# 121
# 21
# ['not divisible', 'not divisible', 'not divisible', 'not divisible', 21]

# %% [markdown]
# **Class8**

# %%
# Generator -> used to generate a values with the help of yield keyword


def mygen(n):
  yield n+6
  yield n+5
  yield n**2
a=mygen(5)
print(next(a))
# Out:
# 11

# %%
print(next(a))
# Out:
# 25

# %%
print(next(a))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-94b12d3903f7> in <module>
# ----> 1 print(next(a))
#
# StopIteration:

# %%
def mygen(n):
  yield n+6
  yield n+5
  yield n**2
for x in mygen(5):
   print(x)
# Out:
# 11
# 10
# 25

# %%
# Assignment 2
# write a program to print the largest and smallest number of the list
# Write a program to delete the alternative numbers in a list
# write a program to delete the odd number in a list and print the even numbers

# %%
# Exception hanndling
print(acvcm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e6949b264d6e> in <module>
#       1 # Exception hanndling
# ----> 2 print(acvcm)
#
# NameError: name 'acvcm' is not defined

# %%
print(2/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-d2c0889640ff> in <module>
# ----> 1 print(2/0)
#
# ZeroDivisionError: division by zero

# %%
try:
  print("asbxcv")
  print("Hello all")
  print(var)
except:
  print("An error occured")
# Out:
# asbxcv
# Hello all
# An error occured

# %%
list1=[1,2,34,5,6]
try:
  print(list1[0])
  print(list1[10])
except:
  print("Invalid index number")
# Out:
# 1
# Invalid index number

# %%
set1=[1,25,25,156,15,45]
try:
  print(set1[2])
  print(set1[7])
except:
  print("error")
# Out:
# 25
# error

# %%
l1=(1,23,4,46,78)
try:
  print(l1[0])
  print(l1[6])
except:
  print("invalid index number")
# Out:
# 1
# invalid index number

# %%
mydict={'a':1,'b':2,'c':3}
try:
  print(mydict['a'])
  print(mydict['d'])
except:
  print('There is an error')
# Out:
# 1
# There is an error

# %%
try:
  num1=int(input("Enter the num1:"))
  num2=int(input("Enter the num2:"))
  num=num1+num2
  print("The sum of two values are",num)
except:
  print("Invalid number")
# Out:
# Enter the num2:1
# The sum of two values are 2

# %%
try:
  num1=int(input("Enter the num1:"))
  num2=int(input("Enter the num2:"))
  num=num1+num2
  print(f"The sum of two values are{num1+num2}")
except:
  print("Invalid number")
# Out:
# Enter the num1:1
# Enter the num2:1
# The sum of two values are2

# %%
num1=10
num2=20
print(f"The values are{num1+num2}")
# Out:
# The values are30

# %%
try:
  a=open("file.txt","r+")
  try:
    a.write("Hello all")
    print(a.read())
  except:
    print("File is not created") 
  finally:
    a.close()
except:
  print("Retry again")

# %%
try:
  print(Exception_handling)
except:
  print("Error occured")
finally:
  print("Partially work done")
# Out:
# Error occured
# Partially work done

# %%
try:
    a=open("Python.txt","r+")
    try:
        a.write("Hello all")
        print(a.read())
    except:
        print("File is not created")
    finally:
        a.close()
except:
    print("Retry again")

# %%
try:
  a=open("filt.txt","w+")
  try:
    a.write("helo")
  except:
    print("failed")
except:
  print("invalid")
finally:
  a.seek(0)
  b=a.read()
  print(b)
  a.close()
# Out:
# helo

# %%
try:
  raise ZeroDivisionError("abcd")
except ZeroDivisionError:
  print("An error occurred")
  raise
# Out:
# An error occurred
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-64-9e18033c3963> in <module>
#       1 try:
# ----> 2   raise ZeroDivisionError("abcd")
#       3 except ZeroDivisionError:
#       4   print("An error occurred")
#       5   raise
#
# ZeroDivisionError: abcd
